# %%
# This notebook contains code showing the many steps I took to get the large citations and metadata downloads processed.
# For documentation/provenance purposes. No need to replicate this. Use the sampled data I got at the end.

# %%
import time
from neo4j import GraphDatabase
import pandas as pd
import numpy as np
import math
import os

# Neo4j connection details
NEO4J_URI = "bolt://localhost:7687"
NEO4J_USER = "neo4j"
NEO4J_PASSWORD = "password" # your password to the local DBMS you created on Neo4j Desktop where you want to upload the data

# %%
# %%time

def filter_citations_with_metadata(citations_file, metadata_file, output_prefix, batch_size=1000000):
    """
    Filter the citations to only include records that have matching metadata
    for both citing and cited papers (based on the 'omid' column in metadata).
    
    Parameters:
        citations_file (str): Path to the CSV file containing citations.
        metadata_file (str): Path to the CSV file containing metadata.
        output_prefix (str): Prefix for the output batch files.
        batch_size (int): Number of original records to process per batch.
    """
    # Load the metadata into a Pandas DataFrame (use 'omid' as the identifier column)
    metadata_df = pd.read_csv(metadata_file, dtype={'omid': 'object'})
    
    # Load the citations data (ensure 'citing' and 'cited' are treated as strings)
    citations_df = pd.read_csv(citations_file, dtype={'citing': 'object', 'cited': 'object'})
    
    # Extract the 'omid' values from metadata (set of valid metadata ids)
    valid_metadata_ids = set(metadata_df['omid'].unique())
    
    # Initialize variables for tracking progress and estimating time
    total_records = len(citations_df)
    processed_records = 0
    start_time = time.time()
    
    # Prepare an empty list to store filtered citations
    filtered_citations = []
    
    # Define the number of batches needed based on total records and batch size
    num_batches = math.ceil(total_records / batch_size)
    
    # Iterate over the citations data
    for _, row in citations_df.iterrows():
        citing_id = row['citing']
        cited_id = row['cited']
        
        # Check if both citing and cited IDs exist in the valid metadata set
        if citing_id in valid_metadata_ids and cited_id in valid_metadata_ids:
            filtered_citations.append(row)
        
        # Update progress and estimate time remaining
        processed_records += 1
        elapsed_time = time.time() - start_time
        remaining_time = (elapsed_time / processed_records) * (total_records - processed_records)
        
        # Print progress every 1000 records
        if processed_records % 100000 == 0 or processed_records == total_records:
            print(f"Processed {processed_records} out of {total_records} original records. "
                  f"Estimated time remaining: {remaining_time / 60:.2f} minutes.")
        
        # If we've processed enough original records for a batch, save that batch
        if processed_records % batch_size == 0:
            batch_df = pd.DataFrame(filtered_citations)
            batch_num = processed_records // batch_size
            batch_df.to_csv(f"{output_prefix}_batch_{batch_num + 1}.csv", index=False)
            print(f"Saved batch {batch_num + 1} with {len(filtered_citations)} filtered records.")
            filtered_citations = []  # Reset for the next batch
    
    # After the loop, save any remaining records that didn't fill a full batch
    if filtered_citations:
        batch_num = num_batches  # The last batch number
        batch_df = pd.DataFrame(filtered_citations)
        batch_df.to_csv(f"{output_prefix}_batch_{batch_num}.csv", index=False)
        print(f"Saved final batch {batch_num} with {len(filtered_citations)} filtered records.")
    
    print(f"Original number of citations: {total_records}")
    print(f"Filtered number of citations: {processed_records}")

# Example usage
citations_file = "filtered_citations.csv"  # Path to your citations file
metadata_file = "filtered_metadata_with_split_ids_4parts.csv"  # Path to your metadata file
output_prefix = "filtered_citations_with_metadata"  # Prefix for the batch output files

# Call the function to filter citations and save in batches
filter_citations_with_metadata(citations_file, metadata_file, output_prefix, batch_size=13000000)
# Out:
# <timed exec>:13: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
# Processed 100000 out of 103094766 original records. Estimated time remaining: 187.26 minutes.
# Processed 200000 out of 103094766 original records. Estimated time remaining: 161.98 minutes.
# Processed 300000 out of 103094766 original records. Estimated time remaining: 150.71 minutes.
# Processed 400000 out of 103094766 original records. Estimated time remaining: 135.24 minutes.
# Processed 500000 out of 103094766 original records. Estimated time remaining: 130.12 minutes.
# Processed 600000 out of 103094766 original records. Estimated time remaining: 126.48 minutes.
# Processed 700000 out of 103094766 original records. Estimated time remaining: 120.18 minutes.
# Processed 800000 out of 103094766 original records. Estimated time remaining: 117.04 minutes.
# Processed 900000 out of 103094766 original records. Estimated time remaining: 111.83 minutes.
# Processed 1000000 out of 103094766 original records. Estimated time remaining: 110.08 minutes.
# Processed 1100000 out of 103094766 original records. Estimated time remaining: 106.45 minutes.
# Processed 1200000 out of 103094766 original records. Estimated time remaining: 103.37 minutes.
# Processed 1300000 out of 103094766 original records. Estimated time remaining: 102.57 minutes.
# Processed 1400000 out of 103094766 original records. Estimated time remaining: 100.21 minutes.
# Processed 1500000 out of 103094766 original records. Estimated time remaining: 98.15 minutes.
# Processed 1600000 out of 103094766 original records. Estimated time remaining: 97.98 minutes.
# Processed 1700000 out of 103094766 original records. Estimated time remaining: 96.54 minutes.
# Processed 1800000 out of 103094766 original records. Estimated time remaining: 95.08 minutes.
# Processed 1900000 out of 103094766 original records. Estimated time remaining: 93.71 minutes.
# Processed 2000000 out of 103094766 original records. Estimated time remaining: 94.21 minutes.
# Processed 2100000 out of 103094766 original records. Estimated time remaining: 93.13 minutes.
# Processed 2200000 out of 103094766 original records. Estimated time remaining: 92.10 minutes.
# Processed 2300000 out of 103094766 original records. Estimated time remaining: 91.20 minutes.
# Processed 2400000 out of 103094766 original records. Estimated time remaining: 90.36 minutes.
# Processed 2500000 out of 103094766 original records. Estimated time remaining: 89.46 minutes.
# Processed 2600000 out of 103094766 original records. Estimated time remaining: 89.81 minutes.
# Processed 2700000 out of 103094766 original records. Estimated time remaining: 89.11 minutes.
# Processed 2800000 out of 103094766 original records. Estimated time remaining: 88.32 minutes.
# Processed 2900000 out of 103094766 original records. Estimated time remaining: 87.58 minutes.
# Processed 3000000 out of 103094766 original records. Estimated time remaining: 86.91 minutes.
# Processed 3100000 out of 103094766 original records. Estimated time remaining: 86.26 minutes.
# Processed 3200000 out of 103094766 original records. Estimated time remaining: 85.71 minutes.
# Processed 3300000 out of 103094766 original records. Estimated time remaining: 86.10 minutes.
# Processed 3400000 out of 103094766 original records. Estimated time remaining: 85.53 minutes.
# Processed 3500000 out of 103094766 original records. Estimated time remaining: 85.00 minutes.
# Processed 3600000 out of 103094766 original records. Estimated time remaining: 84.48 minutes.
# Processed 3700000 out of 103094766 original records. Estimated time remaining: 83.97 minutes.
# Processed 3800000 out of 103094766 original records. Estimated time remaining: 83.51 minutes.
# Processed 3900000 out of 103094766 original records. Estimated time remaining: 83.06 minutes.
# Processed 4000000 out of 103094766 original records. Estimated time remaining: 82.63 minutes.
# Processed 4100000 out of 103094766 original records. Estimated time remaining: 83.11 minutes.
# Processed 4200000 out of 103094766 original records. Estimated time remaining: 82.70 minutes.
# Processed 4300000 out of 103094766 original records. Estimated time remaining: 82.29 minutes.
# Processed 4400000 out of 103094766 original records. Estimated time remaining: 81.91 minutes.
# Processed 4500000 out of 103094766 original records. Estimated time remaining: 81.53 minutes.
# Processed 4600000 out of 103094766 original records. Estimated time remaining: 81.16 minutes.
# Processed 4700000 out of 103094766 original records. Estimated time remaining: 80.91 minutes.
# Processed 4800000 out of 103094766 original records. Estimated time remaining: 80.56 minutes.
# Processed 4900000 out of 103094766 original records. Estimated time remaining: 80.23 minutes.
# Processed 5000000 out of 103094766 original records. Estimated time remaining: 79.92 minutes.
# Processed 5100000 out of 103094766 original records. Estimated time remaining: 80.39 minutes.
# Processed 5200000 out of 103094766 original records. Estimated time remaining: 80.08 minutes.
# Processed 5300000 out of 103094766 original records. Estimated time remaining: 79.78 minutes.
# Processed 5400000 out of 103094766 original records. Estimated time remaining: 79.51 minutes.
# Processed 5500000 out of 103094766 original records. Estimated time remaining: 79.23 minutes.
# Processed 5600000 out of 103094766 original records. Estimated time remaining: 78.95 minutes.
# Processed 5700000 out of 103094766 original records. Estimated time remaining: 78.71 minutes.
# Processed 5800000 out of 103094766 original records. Estimated time remaining: 78.46 minutes.
# Processed 5900000 out of 103094766 original records. Estimated time remaining: 78.21 minutes.
# Processed 6000000 out of 103094766 original records. Estimated time remaining: 77.98 minutes.
# Processed 6100000 out of 103094766 original records. Estimated time remaining: 77.73 minutes.
# Processed 6200000 out of 103094766 original records. Estimated time remaining: 77.49 minutes.
# Processed 6300000 out of 103094766 original records. Estimated time remaining: 77.25 minutes.
# Processed 6400000 out of 103094766 original records. Estimated time remaining: 77.72 minutes.
# Processed 6500000 out of 103094766 original records. Estimated time remaining: 77.49 minutes.
# Processed 6600000 out of 103094766 original records. Estimated time remaining: 77.25 minutes.
# Processed 6700000 out of 103094766 original records. Estimated time remaining: 77.03 minutes.
# Processed 6800000 out of 103094766 original records. Estimated time remaining: 76.80 minutes.
# Processed 6900000 out of 103094766 original records. Estimated time remaining: 76.59 minutes.
# Processed 7000000 out of 103094766 original records. Estimated time remaining: 76.38 minutes.
# Processed 7100000 out of 103094766 original records. Estimated time remaining: 76.16 minutes.
# Processed 7200000 out of 103094766 original records. Estimated time remaining: 75.95 minutes.
# Processed 7300000 out of 103094766 original records. Estimated time remaining: 75.74 minutes.
# Processed 7400000 out of 103094766 original records. Estimated time remaining: 75.60 minutes.
# Processed 7500000 out of 103094766 original records. Estimated time remaining: 75.42 minutes.
# Processed 7600000 out of 103094766 original records. Estimated time remaining: 75.23 minutes.
# Processed 7700000 out of 103094766 original records. Estimated time remaining: 75.04 minutes.
# Processed 7800000 out of 103094766 original records. Estimated time remaining: 74.85 minutes.
# Processed 7900000 out of 103094766 original records. Estimated time remaining: 75.34 minutes.
# Processed 8000000 out of 103094766 original records. Estimated time remaining: 75.15 minutes.
# Processed 8100000 out of 103094766 original records. Estimated time remaining: 74.99 minutes.
# Processed 8200000 out of 103094766 original records. Estimated time remaining: 74.82 minutes.
# Processed 8300000 out of 103094766 original records. Estimated time remaining: 74.67 minutes.
# Processed 8400000 out of 103094766 original records. Estimated time remaining: 74.53 minutes.
# Processed 8500000 out of 103094766 original records. Estimated time remaining: 74.36 minutes.
# Processed 8600000 out of 103094766 original records. Estimated time remaining: 74.19 minutes.
# Processed 8700000 out of 103094766 original records. Estimated time remaining: 74.03 minutes.
# Processed 8800000 out of 103094766 original records. Estimated time remaining: 73.90 minutes.
# Processed 8900000 out of 103094766 original records. Estimated time remaining: 73.74 minutes.
# Processed 9000000 out of 103094766 original records. Estimated time remaining: 73.59 minutes.
# Processed 9100000 out of 103094766 original records. Estimated time remaining: 73.44 minutes.
# Processed 9200000 out of 103094766 original records. Estimated time remaining: 73.28 minutes.
# Processed 9300000 out of 103094766 original records. Estimated time remaining: 73.14 minutes.
# Processed 9400000 out of 103094766 original records. Estimated time remaining: 73.00 minutes.
# Processed 9500000 out of 103094766 original records. Estimated time remaining: 72.85 minutes.
# Processed 9600000 out of 103094766 original records. Estimated time remaining: 72.70 minutes.
# Processed 9700000 out of 103094766 original records. Estimated time remaining: 72.55 minutes.
# Processed 9800000 out of 103094766 original records. Estimated time remaining: 72.41 minutes.
# Processed 9900000 out of 103094766 original records. Estimated time remaining: 73.22 minutes.
# Processed 10000000 out of 103094766 original records. Estimated time remaining: 73.07 minutes.
# Processed 10100000 out of 103094766 original records. Estimated time remaining: 72.91 minutes.
# Processed 10200000 out of 103094766 original records. Estimated time remaining: 72.77 minutes.
# Processed 10300000 out of 103094766 original records. Estimated time remaining: 72.62 minutes.
# Processed 10400000 out of 103094766 original records. Estimated time remaining: 72.48 minutes.
# Processed 10500000 out of 103094766 original records. Estimated time remaining: 72.33 minutes.
# Processed 10600000 out of 103094766 original records. Estimated time remaining: 72.17 minutes.
# Processed 10700000 out of 103094766 original records. Estimated time remaining: 72.03 minutes.
# Processed 10800000 out of 103094766 original records. Estimated time remaining: 71.89 minutes.
# Processed 10900000 out of 103094766 original records. Estimated time remaining: 71.75 minutes.
# Processed 11000000 out of 103094766 original records. Estimated time remaining: 71.61 minutes.
# Processed 11100000 out of 103094766 original records. Estimated time remaining: 71.47 minutes.
# Processed 11200000 out of 103094766 original records. Estimated time remaining: 71.34 minutes.
# Processed 11300000 out of 103094766 original records. Estimated time remaining: 71.20 minutes.
# Processed 11400000 out of 103094766 original records. Estimated time remaining: 71.07 minutes.
# Processed 11500000 out of 103094766 original records. Estimated time remaining: 70.94 minutes.
# Processed 11600000 out of 103094766 original records. Estimated time remaining: 70.80 minutes.
# Processed 11700000 out of 103094766 original records. Estimated time remaining: 70.66 minutes.
# Processed 11800000 out of 103094766 original records. Estimated time remaining: 70.53 minutes.
# Processed 11900000 out of 103094766 original records. Estimated time remaining: 70.41 minutes.
# Processed 12000000 out of 103094766 original records. Estimated time remaining: 70.29 minutes.
# Processed 12100000 out of 103094766 original records. Estimated time remaining: 70.16 minutes.
# Processed 12200000 out of 103094766 original records. Estimated time remaining: 70.03 minutes.
# Processed 12300000 out of 103094766 original records. Estimated time remaining: 69.90 minutes.
# Processed 12400000 out of 103094766 original records. Estimated time remaining: 69.78 minutes.
# Processed 12500000 out of 103094766 original records. Estimated time remaining: 70.18 minutes.
# Processed 12600000 out of 103094766 original records. Estimated time remaining: 70.05 minutes.
# Processed 12700000 out of 103094766 original records. Estimated time remaining: 69.92 minutes.
# Processed 12800000 out of 103094766 original records. Estimated time remaining: 69.79 minutes.
# Processed 12900000 out of 103094766 original records. Estimated time remaining: 69.67 minutes.
# Processed 13000000 out of 103094766 original records. Estimated time remaining: 69.54 minutes.
# Saved batch 2 with 2082601 filtered records.
# Processed 13100000 out of 103094766 original records. Estimated time remaining: 73.17 minutes.
# Processed 13200000 out of 103094766 original records. Estimated time remaining: 73.01 minutes.
# Processed 13300000 out of 103094766 original records. Estimated time remaining: 72.85 minutes.
# Processed 13400000 out of 103094766 original records. Estimated time remaining: 72.70 minutes.
# Processed 13500000 out of 103094766 original records. Estimated time remaining: 72.56 minutes.
# Processed 13600000 out of 103094766 original records. Estimated time remaining: 72.40 minutes.
# Processed 13700000 out of 103094766 original records. Estimated time remaining: 72.25 minutes.
# Processed 13800000 out of 103094766 original records. Estimated time remaining: 72.10 minutes.
# Processed 13900000 out of 103094766 original records. Estimated time remaining: 71.95 minutes.
# Processed 14000000 out of 103094766 original records. Estimated time remaining: 71.80 minutes.
# Processed 14100000 out of 103094766 original records. Estimated time remaining: 71.66 minutes.
# Processed 14200000 out of 103094766 original records. Estimated time remaining: 71.52 minutes.
# Processed 14300000 out of 103094766 original records. Estimated time remaining: 71.37 minutes.
# Processed 14400000 out of 103094766 original records. Estimated time remaining: 71.23 minutes.
# Processed 14500000 out of 103094766 original records. Estimated time remaining: 71.09 minutes.
# Processed 14600000 out of 103094766 original records. Estimated time remaining: 70.95 minutes.
# Processed 14700000 out of 103094766 original records. Estimated time remaining: 70.85 minutes.
# Processed 14800000 out of 103094766 original records. Estimated time remaining: 70.73 minutes.
# Processed 14900000 out of 103094766 original records. Estimated time remaining: 70.60 minutes.
# Processed 15000000 out of 103094766 original records. Estimated time remaining: 70.47 minutes.
# Processed 15100000 out of 103094766 original records. Estimated time remaining: 70.35 minutes.
# Processed 15200000 out of 103094766 original records. Estimated time remaining: 70.22 minutes.
# Processed 15300000 out of 103094766 original records. Estimated time remaining: 70.11 minutes.
# Processed 15400000 out of 103094766 original records. Estimated time remaining: 70.17 minutes.
# Processed 15500000 out of 103094766 original records. Estimated time remaining: 70.04 minutes.
# Processed 15600000 out of 103094766 original records. Estimated time remaining: 69.91 minutes.
# Processed 15700000 out of 103094766 original records. Estimated time remaining: 69.79 minutes.
# Processed 15800000 out of 103094766 original records. Estimated time remaining: 69.68 minutes.
# Processed 15900000 out of 103094766 original records. Estimated time remaining: 69.57 minutes.
# Processed 16000000 out of 103094766 original records. Estimated time remaining: 69.61 minutes.
# Processed 16100000 out of 103094766 original records. Estimated time remaining: 69.48 minutes.
# Processed 16200000 out of 103094766 original records. Estimated time remaining: 69.35 minutes.
# Processed 16300000 out of 103094766 original records. Estimated time remaining: 69.24 minutes.
# Processed 16400000 out of 103094766 original records. Estimated time remaining: 69.14 minutes.
# Processed 16500000 out of 103094766 original records. Estimated time remaining: 69.04 minutes.
# Processed 16600000 out of 103094766 original records. Estimated time remaining: 68.91 minutes.
# Processed 16700000 out of 103094766 original records. Estimated time remaining: 68.79 minutes.
# Processed 16800000 out of 103094766 original records. Estimated time remaining: 68.94 minutes.
# Processed 16900000 out of 103094766 original records. Estimated time remaining: 68.82 minutes.
# Processed 17000000 out of 103094766 original records. Estimated time remaining: 68.71 minutes.
# Processed 17100000 out of 103094766 original records. Estimated time remaining: 68.61 minutes.
# Processed 17200000 out of 103094766 original records. Estimated time remaining: 68.50 minutes.
# Processed 17300000 out of 103094766 original records. Estimated time remaining: 68.39 minutes.
# Processed 17400000 out of 103094766 original records. Estimated time remaining: 68.27 minutes.
# Processed 17500000 out of 103094766 original records. Estimated time remaining: 68.14 minutes.
# Processed 17600000 out of 103094766 original records. Estimated time remaining: 68.02 minutes.
# Processed 17700000 out of 103094766 original records. Estimated time remaining: 68.08 minutes.
# Processed 17800000 out of 103094766 original records. Estimated time remaining: 67.96 minutes.
# Processed 17900000 out of 103094766 original records. Estimated time remaining: 67.84 minutes.
# Processed 18000000 out of 103094766 original records. Estimated time remaining: 67.72 minutes.
# Processed 18100000 out of 103094766 original records. Estimated time remaining: 67.60 minutes.
# Processed 18200000 out of 103094766 original records. Estimated time remaining: 67.47 minutes.
# Processed 18300000 out of 103094766 original records. Estimated time remaining: 67.36 minutes.
# Processed 18400000 out of 103094766 original records. Estimated time remaining: 67.23 minutes.
# Processed 18500000 out of 103094766 original records. Estimated time remaining: 67.11 minutes.
# Processed 18600000 out of 103094766 original records. Estimated time remaining: 66.99 minutes.
# Processed 18700000 out of 103094766 original records. Estimated time remaining: 66.87 minutes.
# Processed 18800000 out of 103094766 original records. Estimated time remaining: 66.76 minutes.
# Processed 18900000 out of 103094766 original records. Estimated time remaining: 66.83 minutes.
# Processed 19000000 out of 103094766 original records. Estimated time remaining: 66.71 minutes.
# Processed 19100000 out of 103094766 original records. Estimated time remaining: 66.59 minutes.
# Processed 19200000 out of 103094766 original records. Estimated time remaining: 66.47 minutes.
# Processed 19300000 out of 103094766 original records. Estimated time remaining: 66.35 minutes.
# Processed 19400000 out of 103094766 original records. Estimated time remaining: 66.23 minutes.
# Processed 19500000 out of 103094766 original records. Estimated time remaining: 66.11 minutes.
# Processed 19600000 out of 103094766 original records. Estimated time remaining: 66.00 minutes.
# Processed 19700000 out of 103094766 original records. Estimated time remaining: 65.88 minutes.
# Processed 19800000 out of 103094766 original records. Estimated time remaining: 65.77 minutes.
# Processed 19900000 out of 103094766 original records. Estimated time remaining: 65.65 minutes.
# Processed 20000000 out of 103094766 original records. Estimated time remaining: 65.54 minutes.
# Processed 20100000 out of 103094766 original records. Estimated time remaining: 65.43 minutes.
# Processed 20200000 out of 103094766 original records. Estimated time remaining: 65.31 minutes.
# Processed 20300000 out of 103094766 original records. Estimated time remaining: 65.20 minutes.
# Processed 20400000 out of 103094766 original records. Estimated time remaining: 65.30 minutes.
# Processed 20500000 out of 103094766 original records. Estimated time remaining: 65.19 minutes.
# Processed 20600000 out of 103094766 original records. Estimated time remaining: 65.07 minutes.
# Processed 20700000 out of 103094766 original records. Estimated time remaining: 64.95 minutes.
# Processed 20800000 out of 103094766 original records. Estimated time remaining: 64.84 minutes.
# Processed 20900000 out of 103094766 original records. Estimated time remaining: 64.72 minutes.
# Processed 21000000 out of 103094766 original records. Estimated time remaining: 64.61 minutes.
# Processed 21100000 out of 103094766 original records. Estimated time remaining: 64.49 minutes.
# Processed 21200000 out of 103094766 original records. Estimated time remaining: 64.38 minutes.
# Processed 21300000 out of 103094766 original records. Estimated time remaining: 64.27 minutes.
# Processed 21400000 out of 103094766 original records. Estimated time remaining: 64.16 minutes.
# Processed 21500000 out of 103094766 original records. Estimated time remaining: 64.06 minutes.
# Processed 21600000 out of 103094766 original records. Estimated time remaining: 63.95 minutes.
# Processed 21700000 out of 103094766 original records. Estimated time remaining: 63.84 minutes.
# Processed 21800000 out of 103094766 original records. Estimated time remaining: 63.73 minutes.
# Processed 21900000 out of 103094766 original records. Estimated time remaining: 63.62 minutes.
# Processed 22000000 out of 103094766 original records. Estimated time remaining: 63.51 minutes.
# Processed 22100000 out of 103094766 original records. Estimated time remaining: 63.40 minutes.
# Processed 22200000 out of 103094766 original records. Estimated time remaining: 63.29 minutes.
# Processed 22300000 out of 103094766 original records. Estimated time remaining: 63.18 minutes.
# Processed 22400000 out of 103094766 original records. Estimated time remaining: 63.30 minutes.
# Processed 22500000 out of 103094766 original records. Estimated time remaining: 63.19 minutes.
# Processed 22600000 out of 103094766 original records. Estimated time remaining: 63.07 minutes.
# Processed 22700000 out of 103094766 original records. Estimated time remaining: 62.97 minutes.
# Processed 22800000 out of 103094766 original records. Estimated time remaining: 62.86 minutes.
# Processed 22900000 out of 103094766 original records. Estimated time remaining: 62.76 minutes.
# Processed 23000000 out of 103094766 original records. Estimated time remaining: 62.65 minutes.
# Processed 23100000 out of 103094766 original records. Estimated time remaining: 62.54 minutes.
# Processed 23200000 out of 103094766 original records. Estimated time remaining: 62.44 minutes.
# Processed 23300000 out of 103094766 original records. Estimated time remaining: 62.33 minutes.
# Processed 23400000 out of 103094766 original records. Estimated time remaining: 62.23 minutes.
# Processed 23500000 out of 103094766 original records. Estimated time remaining: 62.12 minutes.
# Processed 23600000 out of 103094766 original records. Estimated time remaining: 62.01 minutes.
# Processed 23700000 out of 103094766 original records. Estimated time remaining: 61.90 minutes.
# Processed 23800000 out of 103094766 original records. Estimated time remaining: 61.80 minutes.
# Processed 23900000 out of 103094766 original records. Estimated time remaining: 61.69 minutes.
# Processed 24000000 out of 103094766 original records. Estimated time remaining: 61.59 minutes.
# Processed 24100000 out of 103094766 original records. Estimated time remaining: 61.49 minutes.
# Processed 24200000 out of 103094766 original records. Estimated time remaining: 61.38 minutes.
# Processed 24300000 out of 103094766 original records. Estimated time remaining: 61.28 minutes.
# Processed 24400000 out of 103094766 original records. Estimated time remaining: 61.18 minutes.
# Processed 24500000 out of 103094766 original records. Estimated time remaining: 61.08 minutes.
# Processed 24600000 out of 103094766 original records. Estimated time remaining: 60.97 minutes.
# Processed 24700000 out of 103094766 original records. Estimated time remaining: 60.87 minutes.
# Processed 24800000 out of 103094766 original records. Estimated time remaining: 60.77 minutes.
# Processed 24900000 out of 103094766 original records. Estimated time remaining: 60.94 minutes.
# Processed 25000000 out of 103094766 original records. Estimated time remaining: 60.85 minutes.
# Processed 25100000 out of 103094766 original records. Estimated time remaining: 60.74 minutes.
# Processed 25200000 out of 103094766 original records. Estimated time remaining: 60.64 minutes.
# Processed 25300000 out of 103094766 original records. Estimated time remaining: 60.54 minutes.
# Processed 25400000 out of 103094766 original records. Estimated time remaining: 60.44 minutes.
# Processed 25500000 out of 103094766 original records. Estimated time remaining: 60.34 minutes.
# Processed 25600000 out of 103094766 original records. Estimated time remaining: 60.24 minutes.
# Processed 25700000 out of 103094766 original records. Estimated time remaining: 60.14 minutes.
# Processed 25800000 out of 103094766 original records. Estimated time remaining: 60.04 minutes.
# Processed 25900000 out of 103094766 original records. Estimated time remaining: 59.94 minutes.
# Processed 26000000 out of 103094766 original records. Estimated time remaining: 59.84 minutes.
# Saved batch 3 with 2113618 filtered records.
# Processed 26100000 out of 103094766 original records. Estimated time remaining: 61.80 minutes.
# Processed 26200000 out of 103094766 original records. Estimated time remaining: 61.70 minutes.
# Processed 26300000 out of 103094766 original records. Estimated time remaining: 61.60 minutes.
# Processed 26400000 out of 103094766 original records. Estimated time remaining: 61.50 minutes.
# Processed 26500000 out of 103094766 original records. Estimated time remaining: 61.40 minutes.
# Processed 26600000 out of 103094766 original records. Estimated time remaining: 61.33 minutes.
# Processed 26700000 out of 103094766 original records. Estimated time remaining: 61.26 minutes.
# Processed 26800000 out of 103094766 original records. Estimated time remaining: 61.16 minutes.
# Processed 26900000 out of 103094766 original records. Estimated time remaining: 61.06 minutes.
# Processed 27000000 out of 103094766 original records. Estimated time remaining: 60.96 minutes.
# Processed 27100000 out of 103094766 original records. Estimated time remaining: 60.87 minutes.
# Processed 27200000 out of 103094766 original records. Estimated time remaining: 60.77 minutes.
# Processed 27300000 out of 103094766 original records. Estimated time remaining: 60.67 minutes.
# Processed 27400000 out of 103094766 original records. Estimated time remaining: 60.57 minutes.
# Processed 27500000 out of 103094766 original records. Estimated time remaining: 60.47 minutes.
# Processed 27600000 out of 103094766 original records. Estimated time remaining: 60.37 minutes.
# Processed 27700000 out of 103094766 original records. Estimated time remaining: 60.30 minutes.
# Processed 27800000 out of 103094766 original records. Estimated time remaining: 60.23 minutes.
# Processed 27900000 out of 103094766 original records. Estimated time remaining: 60.15 minutes.
# Processed 28000000 out of 103094766 original records. Estimated time remaining: 60.17 minutes.
# Processed 28100000 out of 103094766 original records. Estimated time remaining: 60.07 minutes.
# Processed 28200000 out of 103094766 original records. Estimated time remaining: 59.97 minutes.
# Processed 28300000 out of 103094766 original records. Estimated time remaining: 59.87 minutes.
# Processed 28400000 out of 103094766 original records. Estimated time remaining: 59.85 minutes.
# Processed 28500000 out of 103094766 original records. Estimated time remaining: 59.77 minutes.
# Processed 28600000 out of 103094766 original records. Estimated time remaining: 59.67 minutes.
# Processed 28700000 out of 103094766 original records. Estimated time remaining: 59.57 minutes.
# Processed 28800000 out of 103094766 original records. Estimated time remaining: 59.47 minutes.
# Processed 28900000 out of 103094766 original records. Estimated time remaining: 59.37 minutes.
# Processed 29000000 out of 103094766 original records. Estimated time remaining: 59.35 minutes.
# Processed 29100000 out of 103094766 original records. Estimated time remaining: 59.25 minutes.
# Processed 29200000 out of 103094766 original records. Estimated time remaining: 59.14 minutes.
# Processed 29300000 out of 103094766 original records. Estimated time remaining: 59.04 minutes.
# Processed 29400000 out of 103094766 original records. Estimated time remaining: 58.94 minutes.
# Processed 29500000 out of 103094766 original records. Estimated time remaining: 58.84 minutes.
# Processed 29600000 out of 103094766 original records. Estimated time remaining: 58.74 minutes.
# Processed 29700000 out of 103094766 original records. Estimated time remaining: 58.64 minutes.
# Processed 29800000 out of 103094766 original records. Estimated time remaining: 58.63 minutes.
# Processed 29900000 out of 103094766 original records. Estimated time remaining: 58.53 minutes.
# Processed 30000000 out of 103094766 original records. Estimated time remaining: 58.43 minutes.
# Processed 30100000 out of 103094766 original records. Estimated time remaining: 58.33 minutes.
# Processed 30200000 out of 103094766 original records. Estimated time remaining: 58.23 minutes.
# Processed 30300000 out of 103094766 original records. Estimated time remaining: 58.13 minutes.
# Processed 30400000 out of 103094766 original records. Estimated time remaining: 58.03 minutes.
# Processed 30500000 out of 103094766 original records. Estimated time remaining: 57.93 minutes.
# Processed 30600000 out of 103094766 original records. Estimated time remaining: 57.84 minutes.
# Processed 30700000 out of 103094766 original records. Estimated time remaining: 57.83 minutes.
# Processed 30800000 out of 103094766 original records. Estimated time remaining: 57.74 minutes.
# Processed 30900000 out of 103094766 original records. Estimated time remaining: 57.64 minutes.
# Processed 31000000 out of 103094766 original records. Estimated time remaining: 57.54 minutes.
# Processed 31100000 out of 103094766 original records. Estimated time remaining: 57.44 minutes.
# Processed 31200000 out of 103094766 original records. Estimated time remaining: 57.34 minutes.
# Processed 31300000 out of 103094766 original records. Estimated time remaining: 57.25 minutes.
# Processed 31400000 out of 103094766 original records. Estimated time remaining: 57.15 minutes.
# Processed 31500000 out of 103094766 original records. Estimated time remaining: 57.05 minutes.
# Processed 31600000 out of 103094766 original records. Estimated time remaining: 56.95 minutes.
# Processed 31700000 out of 103094766 original records. Estimated time remaining: 56.85 minutes.
# Processed 31800000 out of 103094766 original records. Estimated time remaining: 56.75 minutes.
# Processed 31900000 out of 103094766 original records. Estimated time remaining: 56.75 minutes.
# Processed 32000000 out of 103094766 original records. Estimated time remaining: 56.66 minutes.
# Processed 32100000 out of 103094766 original records. Estimated time remaining: 56.56 minutes.
# Processed 32200000 out of 103094766 original records. Estimated time remaining: 56.46 minutes.
# Processed 32300000 out of 103094766 original records. Estimated time remaining: 56.36 minutes.
# Processed 32400000 out of 103094766 original records. Estimated time remaining: 56.26 minutes.
# Processed 32500000 out of 103094766 original records. Estimated time remaining: 56.17 minutes.
# Processed 32600000 out of 103094766 original records. Estimated time remaining: 56.09 minutes.
# Processed 32700000 out of 103094766 original records. Estimated time remaining: 56.00 minutes.
# Processed 32800000 out of 103094766 original records. Estimated time remaining: 55.92 minutes.
# Processed 32900000 out of 103094766 original records. Estimated time remaining: 55.83 minutes.
# Processed 33000000 out of 103094766 original records. Estimated time remaining: 55.73 minutes.
# Processed 33100000 out of 103094766 original records. Estimated time remaining: 55.63 minutes.
# Processed 33200000 out of 103094766 original records. Estimated time remaining: 55.54 minutes.
# Processed 33300000 out of 103094766 original records. Estimated time remaining: 55.44 minutes.
# Processed 33400000 out of 103094766 original records. Estimated time remaining: 55.49 minutes.
# Processed 33500000 out of 103094766 original records. Estimated time remaining: 55.40 minutes.
# Processed 33600000 out of 103094766 original records. Estimated time remaining: 55.31 minutes.
# Processed 33700000 out of 103094766 original records. Estimated time remaining: 55.21 minutes.
# Processed 33800000 out of 103094766 original records. Estimated time remaining: 55.11 minutes.
# Processed 33900000 out of 103094766 original records. Estimated time remaining: 55.02 minutes.
# Processed 34000000 out of 103094766 original records. Estimated time remaining: 54.92 minutes.
# Processed 34100000 out of 103094766 original records. Estimated time remaining: 54.82 minutes.
# Processed 34200000 out of 103094766 original records. Estimated time remaining: 54.72 minutes.
# Processed 34300000 out of 103094766 original records. Estimated time remaining: 54.63 minutes.
# Processed 34400000 out of 103094766 original records. Estimated time remaining: 54.53 minutes.
# Processed 34500000 out of 103094766 original records. Estimated time remaining: 54.43 minutes.
# Processed 34600000 out of 103094766 original records. Estimated time remaining: 54.33 minutes.
# Processed 34700000 out of 103094766 original records. Estimated time remaining: 54.23 minutes.
# Processed 34800000 out of 103094766 original records. Estimated time remaining: 54.14 minutes.
# Processed 34900000 out of 103094766 original records. Estimated time remaining: 54.04 minutes.
# Processed 35000000 out of 103094766 original records. Estimated time remaining: 53.94 minutes.
# Processed 35100000 out of 103094766 original records. Estimated time remaining: 53.85 minutes.
# Processed 35200000 out of 103094766 original records. Estimated time remaining: 53.86 minutes.
# Processed 35300000 out of 103094766 original records. Estimated time remaining: 53.76 minutes.
# Processed 35400000 out of 103094766 original records. Estimated time remaining: 53.67 minutes.
# Processed 35500000 out of 103094766 original records. Estimated time remaining: 53.57 minutes.
# Processed 35600000 out of 103094766 original records. Estimated time remaining: 53.47 minutes.
# Processed 35700000 out of 103094766 original records. Estimated time remaining: 53.37 minutes.
# Processed 35800000 out of 103094766 original records. Estimated time remaining: 53.28 minutes.
# Processed 35900000 out of 103094766 original records. Estimated time remaining: 53.18 minutes.
# Processed 36000000 out of 103094766 original records. Estimated time remaining: 53.08 minutes.
# Processed 36100000 out of 103094766 original records. Estimated time remaining: 52.99 minutes.
# Processed 36200000 out of 103094766 original records. Estimated time remaining: 52.89 minutes.
# Processed 36300000 out of 103094766 original records. Estimated time remaining: 52.80 minutes.
# Processed 36400000 out of 103094766 original records. Estimated time remaining: 52.70 minutes.
# Processed 36500000 out of 103094766 original records. Estimated time remaining: 52.60 minutes.
# Processed 36600000 out of 103094766 original records. Estimated time remaining: 52.51 minutes.
# Processed 36700000 out of 103094766 original records. Estimated time remaining: 52.42 minutes.
# Processed 36800000 out of 103094766 original records. Estimated time remaining: 52.32 minutes.
# Processed 36900000 out of 103094766 original records. Estimated time remaining: 52.23 minutes.
# Processed 37000000 out of 103094766 original records. Estimated time remaining: 52.13 minutes.
# Processed 37100000 out of 103094766 original records. Estimated time remaining: 52.03 minutes.
# Processed 37200000 out of 103094766 original records. Estimated time remaining: 51.94 minutes.
# Processed 37300000 out of 103094766 original records. Estimated time remaining: 51.85 minutes.
# Processed 37400000 out of 103094766 original records. Estimated time remaining: 51.75 minutes.
# Processed 37500000 out of 103094766 original records. Estimated time remaining: 51.77 minutes.
# Processed 37600000 out of 103094766 original records. Estimated time remaining: 51.68 minutes.
# Processed 37700000 out of 103094766 original records. Estimated time remaining: 51.59 minutes.
# Processed 37800000 out of 103094766 original records. Estimated time remaining: 51.49 minutes.
# Processed 37900000 out of 103094766 original records. Estimated time remaining: 51.40 minutes.
# Processed 38000000 out of 103094766 original records. Estimated time remaining: 51.30 minutes.
# Processed 38100000 out of 103094766 original records. Estimated time remaining: 51.21 minutes.
# Processed 38200000 out of 103094766 original records. Estimated time remaining: 51.12 minutes.
# Processed 38300000 out of 103094766 original records. Estimated time remaining: 51.03 minutes.
# Processed 38400000 out of 103094766 original records. Estimated time remaining: 50.93 minutes.
# Processed 38500000 out of 103094766 original records. Estimated time remaining: 50.84 minutes.
# Processed 38600000 out of 103094766 original records. Estimated time remaining: 50.74 minutes.
# Processed 38700000 out of 103094766 original records. Estimated time remaining: 50.65 minutes.
# Processed 38800000 out of 103094766 original records. Estimated time remaining: 50.56 minutes.
# Processed 38900000 out of 103094766 original records. Estimated time remaining: 50.47 minutes.
# Processed 39000000 out of 103094766 original records. Estimated time remaining: 50.38 minutes.
# Saved batch 4 with 2130558 filtered records.
# Processed 39100000 out of 103094766 original records. Estimated time remaining: 51.62 minutes.
# Processed 39200000 out of 103094766 original records. Estimated time remaining: 51.54 minutes.
# Processed 39300000 out of 103094766 original records. Estimated time remaining: 51.45 minutes.
# Processed 39400000 out of 103094766 original records. Estimated time remaining: 51.36 minutes.
# Processed 39500000 out of 103094766 original records. Estimated time remaining: 51.26 minutes.
# Processed 39600000 out of 103094766 original records. Estimated time remaining: 51.17 minutes.
# Processed 39700000 out of 103094766 original records. Estimated time remaining: 51.08 minutes.
# Processed 39800000 out of 103094766 original records. Estimated time remaining: 50.99 minutes.
# Processed 39900000 out of 103094766 original records. Estimated time remaining: 50.89 minutes.
# Processed 40000000 out of 103094766 original records. Estimated time remaining: 50.80 minutes.
# Processed 40100000 out of 103094766 original records. Estimated time remaining: 50.70 minutes.
# Processed 40200000 out of 103094766 original records. Estimated time remaining: 50.62 minutes.
# Processed 40300000 out of 103094766 original records. Estimated time remaining: 50.63 minutes.
# Processed 40400000 out of 103094766 original records. Estimated time remaining: 50.54 minutes.
# Processed 40500000 out of 103094766 original records. Estimated time remaining: 50.44 minutes.
# Processed 40600000 out of 103094766 original records. Estimated time remaining: 50.38 minutes.
# Processed 40700000 out of 103094766 original records. Estimated time remaining: 50.29 minutes.
# Processed 40800000 out of 103094766 original records. Estimated time remaining: 50.19 minutes.
# Processed 40900000 out of 103094766 original records. Estimated time remaining: 50.10 minutes.
# Processed 41000000 out of 103094766 original records. Estimated time remaining: 50.05 minutes.
# Processed 41100000 out of 103094766 original records. Estimated time remaining: 49.95 minutes.
# Processed 41200000 out of 103094766 original records. Estimated time remaining: 49.86 minutes.
# Processed 41300000 out of 103094766 original records. Estimated time remaining: 49.76 minutes.
# Processed 41400000 out of 103094766 original records. Estimated time remaining: 49.67 minutes.
# Processed 41500000 out of 103094766 original records. Estimated time remaining: 49.57 minutes.
# Processed 41600000 out of 103094766 original records. Estimated time remaining: 49.52 minutes.
# Processed 41700000 out of 103094766 original records. Estimated time remaining: 49.42 minutes.
# Processed 41800000 out of 103094766 original records. Estimated time remaining: 49.33 minutes.
# Processed 41900000 out of 103094766 original records. Estimated time remaining: 49.23 minutes.
# Processed 42000000 out of 103094766 original records. Estimated time remaining: 49.14 minutes.
# Processed 42100000 out of 103094766 original records. Estimated time remaining: 49.04 minutes.
# Processed 42200000 out of 103094766 original records. Estimated time remaining: 49.00 minutes.
# Processed 42300000 out of 103094766 original records. Estimated time remaining: 48.90 minutes.
# Processed 42400000 out of 103094766 original records. Estimated time remaining: 48.81 minutes.
# Processed 42500000 out of 103094766 original records. Estimated time remaining: 48.71 minutes.
# Processed 42600000 out of 103094766 original records. Estimated time remaining: 48.62 minutes.
# Processed 42700000 out of 103094766 original records. Estimated time remaining: 48.53 minutes.
# Processed 42800000 out of 103094766 original records. Estimated time remaining: 48.43 minutes.
# Processed 42900000 out of 103094766 original records. Estimated time remaining: 48.34 minutes.
# Processed 43000000 out of 103094766 original records. Estimated time remaining: 48.30 minutes.
# Processed 43100000 out of 103094766 original records. Estimated time remaining: 48.20 minutes.
# Processed 43200000 out of 103094766 original records. Estimated time remaining: 48.11 minutes.
# Processed 43300000 out of 103094766 original records. Estimated time remaining: 48.02 minutes.
# Processed 43400000 out of 103094766 original records. Estimated time remaining: 47.93 minutes.
# Processed 43500000 out of 103094766 original records. Estimated time remaining: 47.83 minutes.
# Processed 43600000 out of 103094766 original records. Estimated time remaining: 47.74 minutes.
# Processed 43700000 out of 103094766 original records. Estimated time remaining: 47.65 minutes.
# Processed 43800000 out of 103094766 original records. Estimated time remaining: 47.56 minutes.
# Processed 43900000 out of 103094766 original records. Estimated time remaining: 47.47 minutes.
# Processed 44000000 out of 103094766 original records. Estimated time remaining: 47.44 minutes.
# Processed 44100000 out of 103094766 original records. Estimated time remaining: 47.34 minutes.
# Processed 44200000 out of 103094766 original records. Estimated time remaining: 47.25 minutes.
# Processed 44300000 out of 103094766 original records. Estimated time remaining: 47.16 minutes.
# Processed 44400000 out of 103094766 original records. Estimated time remaining: 47.07 minutes.
# Processed 44500000 out of 103094766 original records. Estimated time remaining: 46.98 minutes.
# Processed 44600000 out of 103094766 original records. Estimated time remaining: 46.89 minutes.
# Processed 44700000 out of 103094766 original records. Estimated time remaining: 46.79 minutes.
# Processed 44800000 out of 103094766 original records. Estimated time remaining: 46.70 minutes.
# Processed 44900000 out of 103094766 original records. Estimated time remaining: 46.61 minutes.
# Processed 45000000 out of 103094766 original records. Estimated time remaining: 46.52 minutes.
# Processed 45100000 out of 103094766 original records. Estimated time remaining: 46.43 minutes.
# Processed 45200000 out of 103094766 original records. Estimated time remaining: 46.40 minutes.
# Processed 45300000 out of 103094766 original records. Estimated time remaining: 46.31 minutes.
# Processed 45400000 out of 103094766 original records. Estimated time remaining: 46.22 minutes.
# Processed 45500000 out of 103094766 original records. Estimated time remaining: 46.12 minutes.
# Processed 45600000 out of 103094766 original records. Estimated time remaining: 46.03 minutes.
# Processed 45700000 out of 103094766 original records. Estimated time remaining: 45.94 minutes.
# Processed 45800000 out of 103094766 original records. Estimated time remaining: 45.85 minutes.
# Processed 45900000 out of 103094766 original records. Estimated time remaining: 45.75 minutes.
# Processed 46000000 out of 103094766 original records. Estimated time remaining: 45.66 minutes.
# Processed 46100000 out of 103094766 original records. Estimated time remaining: 45.57 minutes.
# Processed 46200000 out of 103094766 original records. Estimated time remaining: 45.48 minutes.
# Processed 46300000 out of 103094766 original records. Estimated time remaining: 45.39 minutes.
# Processed 46400000 out of 103094766 original records. Estimated time remaining: 45.30 minutes.
# Processed 46500000 out of 103094766 original records. Estimated time remaining: 45.22 minutes.
# Processed 46600000 out of 103094766 original records. Estimated time remaining: 45.13 minutes.
# Processed 46700000 out of 103094766 original records. Estimated time remaining: 45.04 minutes.
# Processed 46800000 out of 103094766 original records. Estimated time remaining: 45.03 minutes.
# Processed 46900000 out of 103094766 original records. Estimated time remaining: 44.94 minutes.
# Processed 47000000 out of 103094766 original records. Estimated time remaining: 44.85 minutes.
# Processed 47100000 out of 103094766 original records. Estimated time remaining: 44.76 minutes.
# Processed 47200000 out of 103094766 original records. Estimated time remaining: 44.67 minutes.
# Processed 47300000 out of 103094766 original records. Estimated time remaining: 44.58 minutes.
# Processed 47400000 out of 103094766 original records. Estimated time remaining: 44.49 minutes.
# Processed 47500000 out of 103094766 original records. Estimated time remaining: 44.40 minutes.
# Processed 47600000 out of 103094766 original records. Estimated time remaining: 44.31 minutes.
# Processed 47700000 out of 103094766 original records. Estimated time remaining: 44.22 minutes.
# Processed 47800000 out of 103094766 original records. Estimated time remaining: 44.13 minutes.
# Processed 47900000 out of 103094766 original records. Estimated time remaining: 44.04 minutes.
# Processed 48000000 out of 103094766 original records. Estimated time remaining: 43.95 minutes.
# Processed 48100000 out of 103094766 original records. Estimated time remaining: 43.86 minutes.
# Processed 48200000 out of 103094766 original records. Estimated time remaining: 43.77 minutes.
# Processed 48300000 out of 103094766 original records. Estimated time remaining: 43.68 minutes.
# Processed 48400000 out of 103094766 original records. Estimated time remaining: 43.59 minutes.
# Processed 48500000 out of 103094766 original records. Estimated time remaining: 43.50 minutes.
# Processed 48600000 out of 103094766 original records. Estimated time remaining: 43.41 minutes.
# Processed 48700000 out of 103094766 original records. Estimated time remaining: 43.32 minutes.
# Processed 48800000 out of 103094766 original records. Estimated time remaining: 43.30 minutes.
# Processed 48900000 out of 103094766 original records. Estimated time remaining: 43.21 minutes.
# Processed 49000000 out of 103094766 original records. Estimated time remaining: 43.12 minutes.
# Processed 49100000 out of 103094766 original records. Estimated time remaining: 43.03 minutes.
# Processed 49200000 out of 103094766 original records. Estimated time remaining: 42.95 minutes.
# Processed 49300000 out of 103094766 original records. Estimated time remaining: 42.86 minutes.
# Processed 49400000 out of 103094766 original records. Estimated time remaining: 42.77 minutes.
# Processed 49500000 out of 103094766 original records. Estimated time remaining: 42.68 minutes.
# Processed 49600000 out of 103094766 original records. Estimated time remaining: 42.59 minutes.
# Processed 49700000 out of 103094766 original records. Estimated time remaining: 42.50 minutes.
# Processed 49800000 out of 103094766 original records. Estimated time remaining: 42.42 minutes.
# Processed 49900000 out of 103094766 original records. Estimated time remaining: 42.33 minutes.
# Processed 50000000 out of 103094766 original records. Estimated time remaining: 42.24 minutes.
# Processed 50100000 out of 103094766 original records. Estimated time remaining: 42.15 minutes.
# Processed 50200000 out of 103094766 original records. Estimated time remaining: 42.06 minutes.
# Processed 50300000 out of 103094766 original records. Estimated time remaining: 41.98 minutes.
# ...
# Processed 86600000 out of 103094766 original records. Estimated time remaining: 13.27 minutes.
# Processed 86700000 out of 103094766 original records. Estimated time remaining: 13.18 minutes.
# Processed 86800000 out of 103094766 original records. Estimated time remaining: 13.10 minutes.
# Processed 86900000 out of 103094766 original records. Estimated time remaining: 13.02 minutes.
# Processed 87000000 out of 103094766 original records. Estimated time remaining: 12.94 minutes.
# Processed 87100000 out of 103094766 original records. Estimated time remaining: 12.86 minutes.
# Processed 87200000 out of 103094766 original records. Estimated time remaining: 12.77 minutes.
# Processed 87300000 out of 103094766 original records. Estimated time remaining: 12.69 minutes.
# Processed 87400000 out of 103094766 original records. Estimated time remaining: 12.61 minutes.
# Processed 87500000 out of 103094766 original records. Estimated time remaining: 12.53 minutes.
# Processed 87600000 out of 103094766 original records. Estimated time remaining: 12.45 minutes.
# Processed 87700000 out of 103094766 original records. Estimated time remaining: 12.36 minutes.
# Processed 87800000 out of 103094766 original records. Estimated time remaining: 12.28 minutes.
# Processed 87900000 out of 103094766 original records. Estimated time remaining: 12.20 minutes.
# Processed 88000000 out of 103094766 original records. Estimated time remaining: 12.12 minutes.
# Processed 88100000 out of 103094766 original records. Estimated time remaining: 12.04 minutes.
# Processed 88200000 out of 103094766 original records. Estimated time remaining: 11.96 minutes.
# Processed 88300000 out of 103094766 original records. Estimated time remaining: 11.87 minutes.
# Processed 88400000 out of 103094766 original records. Estimated time remaining: 11.79 minutes.
# Processed 88500000 out of 103094766 original records. Estimated time remaining: 11.71 minutes.
# Processed 88600000 out of 103094766 original records. Estimated time remaining: 11.63 minutes.
# Processed 88700000 out of 103094766 original records. Estimated time remaining: 11.55 minutes.
# Processed 88800000 out of 103094766 original records. Estimated time remaining: 11.48 minutes.
# Processed 88900000 out of 103094766 original records. Estimated time remaining: 11.40 minutes.
# Processed 89000000 out of 103094766 original records. Estimated time remaining: 11.32 minutes.
# Processed 89100000 out of 103094766 original records. Estimated time remaining: 11.24 minutes.
# Processed 89200000 out of 103094766 original records. Estimated time remaining: 11.15 minutes.
# Processed 89300000 out of 103094766 original records. Estimated time remaining: 11.07 minutes.
# Processed 89400000 out of 103094766 original records. Estimated time remaining: 10.99 minutes.
# Processed 89500000 out of 103094766 original records. Estimated time remaining: 10.91 minutes.
# Processed 89600000 out of 103094766 original records. Estimated time remaining: 10.83 minutes.
# Processed 89700000 out of 103094766 original records. Estimated time remaining: 10.75 minutes.
# Processed 89800000 out of 103094766 original records. Estimated time remaining: 10.66 minutes.
# Processed 89900000 out of 103094766 original records. Estimated time remaining: 10.58 minutes.
# Processed 90000000 out of 103094766 original records. Estimated time remaining: 10.50 minutes.
# Processed 90100000 out of 103094766 original records. Estimated time remaining: 10.42 minutes.
# Processed 90200000 out of 103094766 original records. Estimated time remaining: 10.34 minutes.
# Processed 90300000 out of 103094766 original records. Estimated time remaining: 10.26 minutes.
# Processed 90400000 out of 103094766 original records. Estimated time remaining: 10.18 minutes.
# Processed 90500000 out of 103094766 original records. Estimated time remaining: 10.09 minutes.
# Processed 90600000 out of 103094766 original records. Estimated time remaining: 10.01 minutes.
# Processed 90700000 out of 103094766 original records. Estimated time remaining: 9.93 minutes.
# Processed 90800000 out of 103094766 original records. Estimated time remaining: 9.85 minutes.
# Processed 90900000 out of 103094766 original records. Estimated time remaining: 9.77 minutes.
# Processed 91000000 out of 103094766 original records. Estimated time remaining: 9.69 minutes.
# Saved batch 8 with 2137373 filtered records.
# Processed 91100000 out of 103094766 original records. Estimated time remaining: 9.72 minutes.
# Processed 91200000 out of 103094766 original records. Estimated time remaining: 9.64 minutes.
# Processed 91300000 out of 103094766 original records. Estimated time remaining: 9.55 minutes.
# Processed 91400000 out of 103094766 original records. Estimated time remaining: 9.47 minutes.
# Processed 91500000 out of 103094766 original records. Estimated time remaining: 9.40 minutes.
# Processed 91600000 out of 103094766 original records. Estimated time remaining: 9.32 minutes.
# Processed 91700000 out of 103094766 original records. Estimated time remaining: 9.23 minutes.
# Processed 91800000 out of 103094766 original records. Estimated time remaining: 9.15 minutes.
# Processed 91900000 out of 103094766 original records. Estimated time remaining: 9.07 minutes.
# Processed 92000000 out of 103094766 original records. Estimated time remaining: 8.99 minutes.
# Processed 92100000 out of 103094766 original records. Estimated time remaining: 8.91 minutes.
# Processed 92200000 out of 103094766 original records. Estimated time remaining: 8.83 minutes.
# Processed 92300000 out of 103094766 original records. Estimated time remaining: 8.75 minutes.
# Processed 92400000 out of 103094766 original records. Estimated time remaining: 8.67 minutes.
# Processed 92500000 out of 103094766 original records. Estimated time remaining: 8.58 minutes.
# Processed 92600000 out of 103094766 original records. Estimated time remaining: 8.50 minutes.
# Processed 92700000 out of 103094766 original records. Estimated time remaining: 8.42 minutes.
# Processed 92800000 out of 103094766 original records. Estimated time remaining: 8.34 minutes.
# Processed 92900000 out of 103094766 original records. Estimated time remaining: 8.26 minutes.
# Processed 93000000 out of 103094766 original records. Estimated time remaining: 8.18 minutes.
# Processed 93100000 out of 103094766 original records. Estimated time remaining: 8.10 minutes.
# Processed 93200000 out of 103094766 original records. Estimated time remaining: 8.01 minutes.
# Processed 93300000 out of 103094766 original records. Estimated time remaining: 7.93 minutes.
# Processed 93400000 out of 103094766 original records. Estimated time remaining: 7.85 minutes.
# Processed 93500000 out of 103094766 original records. Estimated time remaining: 7.77 minutes.
# Processed 93600000 out of 103094766 original records. Estimated time remaining: 7.69 minutes.
# Processed 93700000 out of 103094766 original records. Estimated time remaining: 7.61 minutes.
# Processed 93800000 out of 103094766 original records. Estimated time remaining: 7.53 minutes.
# Processed 93900000 out of 103094766 original records. Estimated time remaining: 7.44 minutes.
# Processed 94000000 out of 103094766 original records. Estimated time remaining: 7.36 minutes.
# Processed 94100000 out of 103094766 original records. Estimated time remaining: 7.28 minutes.
# Processed 94200000 out of 103094766 original records. Estimated time remaining: 7.20 minutes.
# Processed 94300000 out of 103094766 original records. Estimated time remaining: 7.12 minutes.
# Processed 94400000 out of 103094766 original records. Estimated time remaining: 7.04 minutes.
# Processed 94500000 out of 103094766 original records. Estimated time remaining: 6.96 minutes.
# Processed 94600000 out of 103094766 original records. Estimated time remaining: 6.87 minutes.
# Processed 94700000 out of 103094766 original records. Estimated time remaining: 6.79 minutes.
# Processed 94800000 out of 103094766 original records. Estimated time remaining: 6.71 minutes.
# Processed 94900000 out of 103094766 original records. Estimated time remaining: 6.63 minutes.
# Processed 95000000 out of 103094766 original records. Estimated time remaining: 6.55 minutes.
# Processed 95100000 out of 103094766 original records. Estimated time remaining: 6.47 minutes.
# Processed 95200000 out of 103094766 original records. Estimated time remaining: 6.39 minutes.
# Processed 95300000 out of 103094766 original records. Estimated time remaining: 6.30 minutes.
# Processed 95400000 out of 103094766 original records. Estimated time remaining: 6.22 minutes.
# Processed 95500000 out of 103094766 original records. Estimated time remaining: 6.14 minutes.
# Processed 95600000 out of 103094766 original records. Estimated time remaining: 6.06 minutes.
# Processed 95700000 out of 103094766 original records. Estimated time remaining: 5.98 minutes.
# Processed 95800000 out of 103094766 original records. Estimated time remaining: 5.90 minutes.
# Processed 95900000 out of 103094766 original records. Estimated time remaining: 5.81 minutes.
# Processed 96000000 out of 103094766 original records. Estimated time remaining: 5.73 minutes.
# Processed 96100000 out of 103094766 original records. Estimated time remaining: 5.65 minutes.
# Processed 96200000 out of 103094766 original records. Estimated time remaining: 5.57 minutes.
# Processed 96300000 out of 103094766 original records. Estimated time remaining: 5.49 minutes.
# Processed 96400000 out of 103094766 original records. Estimated time remaining: 5.41 minutes.
# Processed 96500000 out of 103094766 original records. Estimated time remaining: 5.33 minutes.
# Processed 96600000 out of 103094766 original records. Estimated time remaining: 5.25 minutes.
# Processed 96700000 out of 103094766 original records. Estimated time remaining: 5.17 minutes.
# Processed 96800000 out of 103094766 original records. Estimated time remaining: 5.08 minutes.
# Processed 96900000 out of 103094766 original records. Estimated time remaining: 5.00 minutes.
# Processed 97000000 out of 103094766 original records. Estimated time remaining: 4.92 minutes.
# Processed 97100000 out of 103094766 original records. Estimated time remaining: 4.84 minutes.
# Processed 97200000 out of 103094766 original records. Estimated time remaining: 4.76 minutes.
# Processed 97300000 out of 103094766 original records. Estimated time remaining: 4.68 minutes.
# Processed 97400000 out of 103094766 original records. Estimated time remaining: 4.60 minutes.
# Processed 97500000 out of 103094766 original records. Estimated time remaining: 4.52 minutes.
# Processed 97600000 out of 103094766 original records. Estimated time remaining: 4.44 minutes.
# Processed 97700000 out of 103094766 original records. Estimated time remaining: 4.36 minutes.
# Processed 97800000 out of 103094766 original records. Estimated time remaining: 4.28 minutes.
# Processed 97900000 out of 103094766 original records. Estimated time remaining: 4.20 minutes.
# Processed 98000000 out of 103094766 original records. Estimated time remaining: 4.12 minutes.
# Processed 98100000 out of 103094766 original records. Estimated time remaining: 4.03 minutes.
# Processed 98200000 out of 103094766 original records. Estimated time remaining: 3.95 minutes.
# Processed 98300000 out of 103094766 original records. Estimated time remaining: 3.87 minutes.
# Processed 98400000 out of 103094766 original records. Estimated time remaining: 3.79 minutes.
# Processed 98500000 out of 103094766 original records. Estimated time remaining: 3.71 minutes.
# Processed 98600000 out of 103094766 original records. Estimated time remaining: 3.63 minutes.
# Processed 98700000 out of 103094766 original records. Estimated time remaining: 3.55 minutes.
# Processed 98800000 out of 103094766 original records. Estimated time remaining: 3.47 minutes.
# Processed 98900000 out of 103094766 original records. Estimated time remaining: 3.38 minutes.
# Processed 99000000 out of 103094766 original records. Estimated time remaining: 3.30 minutes.
# Processed 99100000 out of 103094766 original records. Estimated time remaining: 3.22 minutes.
# Processed 99200000 out of 103094766 original records. Estimated time remaining: 3.14 minutes.
# Processed 99300000 out of 103094766 original records. Estimated time remaining: 3.06 minutes.
# Processed 99400000 out of 103094766 original records. Estimated time remaining: 2.98 minutes.
# Processed 99500000 out of 103094766 original records. Estimated time remaining: 2.90 minutes.
# Processed 99600000 out of 103094766 original records. Estimated time remaining: 2.82 minutes.
# Processed 99700000 out of 103094766 original records. Estimated time remaining: 2.74 minutes.
# Processed 99800000 out of 103094766 original records. Estimated time remaining: 2.66 minutes.
# Processed 99900000 out of 103094766 original records. Estimated time remaining: 2.58 minutes.
# Processed 100000000 out of 103094766 original records. Estimated time remaining: 2.50 minutes.
# Processed 100100000 out of 103094766 original records. Estimated time remaining: 2.41 minutes.
# Processed 100200000 out of 103094766 original records. Estimated time remaining: 2.33 minutes.
# Processed 100300000 out of 103094766 original records. Estimated time remaining: 2.25 minutes.
# Processed 100400000 out of 103094766 original records. Estimated time remaining: 2.17 minutes.
# Processed 100500000 out of 103094766 original records. Estimated time remaining: 2.09 minutes.
# Processed 100600000 out of 103094766 original records. Estimated time remaining: 2.01 minutes.
# Processed 100700000 out of 103094766 original records. Estimated time remaining: 1.93 minutes.
# Processed 100800000 out of 103094766 original records. Estimated time remaining: 1.85 minutes.
# Processed 100900000 out of 103094766 original records. Estimated time remaining: 1.77 minutes.
# Processed 101000000 out of 103094766 original records. Estimated time remaining: 1.69 minutes.
# Processed 101100000 out of 103094766 original records. Estimated time remaining: 1.61 minutes.
# Processed 101200000 out of 103094766 original records. Estimated time remaining: 1.53 minutes.
# Processed 101300000 out of 103094766 original records. Estimated time remaining: 1.45 minutes.
# Processed 101400000 out of 103094766 original records. Estimated time remaining: 1.37 minutes.
# Processed 101500000 out of 103094766 original records. Estimated time remaining: 1.28 minutes.
# Processed 101600000 out of 103094766 original records. Estimated time remaining: 1.20 minutes.
# Processed 101700000 out of 103094766 original records. Estimated time remaining: 1.12 minutes.
# Processed 101800000 out of 103094766 original records. Estimated time remaining: 1.04 minutes.
# Processed 101900000 out of 103094766 original records. Estimated time remaining: 0.96 minutes.
# Processed 102000000 out of 103094766 original records. Estimated time remaining: 0.88 minutes.
# Processed 102100000 out of 103094766 original records. Estimated time remaining: 0.80 minutes.
# Processed 102200000 out of 103094766 original records. Estimated time remaining: 0.72 minutes.
# Processed 102300000 out of 103094766 original records. Estimated time remaining: 0.64 minutes.
# Processed 102400000 out of 103094766 original records. Estimated time remaining: 0.56 minutes.
# Processed 102500000 out of 103094766 original records. Estimated time remaining: 0.48 minutes.
# Processed 102600000 out of 103094766 original records. Estimated time remaining: 0.40 minutes.
# Processed 102700000 out of 103094766 original records. Estimated time remaining: 0.32 minutes.
# Processed 102800000 out of 103094766 original records. Estimated time remaining: 0.24 minutes.
# Processed 102900000 out of 103094766 original records. Estimated time remaining: 0.16 minutes.
# Processed 103000000 out of 103094766 original records. Estimated time remaining: 0.08 minutes.
# Processed 103094766 out of 103094766 original records. Estimated time remaining: 0.00 minutes.
# Saved final batch 8 with 2030152 filtered records.
# Original number of citations: 103094766
# Filtered number of citations: 103094766
# CPU times: user 1h 25min 12s, sys: 8min 4s, total: 1h 33min 17s
# Wall time: 1h 38min 54s

# %%
# %%time

def concatenate_batch_files(batch_file_prefix, output_file, batch_count):
    """
    Concatenate all batch files into a single CSV file.

    Parameters:
        batch_file_prefix (str): Prefix of the batch files (e.g., "filtered_citations_with_metadata_batch_").
        output_file (str): Path to save the concatenated CSV.
        batch_count (int): Total number of batch files to concatenate.
    """
    # List to hold DataFrames from all batch files
    all_batches = []
    
    # Iterate through all batch files and read them into DataFrames
    for i in range(1, batch_count + 1):
        batch_file = f"{batch_file_prefix}_{i}.csv"
        if os.path.exists(batch_file):  # Check if the batch file exists
            print(f"Reading {batch_file}...")
            batch_df = pd.read_csv(batch_file)
            all_batches.append(batch_df)
        else:
            print(f"Warning: {batch_file} does not exist!")
    
    # Concatenate all DataFrames into one
    if all_batches:
        concatenated_df = pd.concat(all_batches, ignore_index=True)
        print(f"Concatenated {len(all_batches)} batch files.")
        
        # Save the concatenated DataFrame to the output file
        concatenated_df.to_csv(output_file, index=False)
        print(f"Saved concatenated file to {output_file}")
    else:
        print("No valid batch files found to concatenate.")

# Example usage:
batch_file_prefix = "filtered_metadata_batch"  # Prefix for batch files
output_file = "all_filtered_metadata.csv"  # Output file to save the concatenated CSV
batch_count = 8  # Total number of batch files you want to concatenate (adjust based on your situation)

# Call the function to concatenate the batch files
concatenate_batch_files(batch_file_prefix, output_file, batch_count)
# Out:
# Reading filtered_metadata_batch_1.csv...
# Reading filtered_metadata_batch_2.csv...
# Reading filtered_metadata_batch_3.csv...
# Reading filtered_metadata_batch_4.csv...
# Reading filtered_metadata_batch_5.csv...
# Reading filtered_metadata_batch_6.csv...
# Reading filtered_metadata_batch_7.csv...
# Reading filtered_metadata_batch_8.csv...
# Concatenated 8 batch files.
# Saved concatenated file to all_filtered_metadata.csv
# CPU times: user 2min 35s, sys: 14.1 s, total: 2min 49s
# Wall time: 2min 50s

# %%
# %%time

# Constants for batch processing
BATCH_SIZE = 1000000  # Adjust batch size as needed
OUTPUT_FILE_PREFIX = "filtered_metadata_batch"
CITATIONS_FILE = "all_filtered_citations.csv"
METADATA_FILE = "filtered_metadata_with_split_ids_4parts.csv"

def filter_metadata_by_citations(citations_file, metadata_file, output_file_prefix, batch_size):
    """
    Filter the metadata based on the omid in citing/cited columns from the citations file and save in batches.

    Parameters:
        citations_file (str): Path to the citations file.
        metadata_file (str): Path to the metadata file.
        output_file_prefix (str): Prefix for the output batch files.
        batch_size (int): The number of records to process in each batch.
    """
    # Load citations data (citing and cited columns only)
    print("Loading citations data...")
    citations_df = pd.read_csv(citations_file, usecols=['citing', 'cited'], dtype={'citing': 'object', 'cited': 'object'})
    
    # Combine citing and cited columns into a single set of unique omids
    omid_set = set(citations_df['citing'].dropna().unique()).union(citations_df['cited'].dropna().unique())
    print(f"Extracted {len(omid_set)} unique omids from citations.")
    
    # Load metadata file
    print("Loading metadata file...")
    metadata_df = pd.read_csv(metadata_file, dtype={'omid': 'object'})

    # Filter metadata to include only records where omid is in omid_set
    filtered_metadata_df = metadata_df[metadata_df['omid'].isin(omid_set)]
    print(f"Filtered metadata to {len(filtered_metadata_df)} records matching omids from citations.")

    # Process and save in batches
    total_records = len(filtered_metadata_df)
    start_time = time.time()
    processed_records = 0
    batch_count = 0

    for start in range(0, total_records, batch_size):
        # Get the chunk (batch) of data
        batch_df = filtered_metadata_df.iloc[start:start + batch_size]
        
        # Save the batch to a CSV file
        batch_count += 1
        batch_output_file = f"{output_file_prefix}_{batch_count}.csv"
        batch_df.to_csv(batch_output_file, index=False)
        print(f"Saved batch {batch_count} to {batch_output_file}")
        
        # Update progress and time remaining estimate
        processed_records += len(batch_df)
        elapsed_time = time.time() - start_time
        remaining_time = (elapsed_time / processed_records) * (total_records - processed_records)
        print(f"Processed {processed_records} out of {total_records} records. Estimated time remaining: {remaining_time / 60:.2f} minutes.")
    
    print("Filtering and batch saving complete.")

# Example usage:
filter_metadata_by_citations(CITATIONS_FILE, METADATA_FILE, OUTPUT_FILE_PREFIX, BATCH_SIZE)
# Out:
# Loading citations data...
# Extracted 7999487 unique omids from citations.
# Loading metadata file...
# <timed exec>:27: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
# Filtered metadata to 7999487 records matching omids from citations.
# Saved batch 1 to filtered_metadata_batch_1.csv
# Processed 1000000 out of 7999487 records. Estimated time remaining: 2.22 minutes.
# Saved batch 2 to filtered_metadata_batch_2.csv
# Processed 2000000 out of 7999487 records. Estimated time remaining: 1.96 minutes.
# Saved batch 3 to filtered_metadata_batch_3.csv
# Processed 3000000 out of 7999487 records. Estimated time remaining: 1.68 minutes.
# Saved batch 4 to filtered_metadata_batch_4.csv
# Processed 4000000 out of 7999487 records. Estimated time remaining: 1.38 minutes.
# Saved batch 5 to filtered_metadata_batch_5.csv
# Processed 5000000 out of 7999487 records. Estimated time remaining: 1.05 minutes.
# Saved batch 6 to filtered_metadata_batch_6.csv
# Processed 6000000 out of 7999487 records. Estimated time remaining: 0.71 minutes.
# Saved batch 7 to filtered_metadata_batch_7.csv
# Processed 7000000 out of 7999487 records. Estimated time remaining: 0.36 minutes.
# Saved batch 8 to filtered_metadata_batch_8.csv
# Processed 7999487 out of 7999487 records. Estimated time remaining: 0.00 minutes.
# Filtering and batch saving complete.
# CPU times: user 5min 28s, sys: 3min 52s, total: 9min 21s
# Wall time: 11min 56s

# %%
# File paths
CITATIONS_FILE = "all_filtered_citations.csv"
SAMPLED_CITATIONS_FILE = "sampled_citations.csv"
METADATA_BATCHES = [f"filtered_metadata_batch_{i}.csv" for i in range(1, 9)]  # filtered_metadata_batch_1.csv through filtered_metadata_batch_8.csv
SAMPLED_METADATA_FILE = "sampled_citations_metadata.csv"

# Parameters
SAMPLE_SIZE = 500  # Random sample size for the initial citation selection
MAX_ITERATIONS = 3  # Limit iterations to avoid infinite loops or long processing times

# Function to sample citations and iteratively filter based on citing/cited IDs
def sample_and_filter_citations(citations_file, sample_size=500, max_iterations=10):
    """
    Randomly sample citations, and iteratively filter based on citing/cited IDs.
    
    Parameters:
        citations_file (str): Path to the all_filtered_citations.csv file.
        sample_size (int): The number of records to randomly sample.
        max_iterations (int): Maximum number of iterations to perform when filtering.
    
    Returns:
        pd.DataFrame: Filtered citations after iterative matching.
    """
    # Load citations file in chunks (use a smaller chunk size to manage memory)
    chunk_size = 1000000
    sampled_citations = []
    first_pass = True
    
    start_time = time.time()
    for chunk in pd.read_csv(citations_file, chunksize=chunk_size):
        # Randomly sample `sample_size` citations from the current chunk
        if first_pass:
            # Sample from the entire citations file randomly
            sampled_chunk = chunk.sample(n=sample_size, random_state=42)
            sampled_citations = sampled_chunk[['id', 'citing', 'cited']]
            first_pass = False
        else:
            # Iteratively filter based on citing/cited IDs matching any of the previously sampled IDs
            sampled_ids = set(sampled_citations['citing']).union(set(sampled_citations['cited']))
            filtered_chunk = chunk[chunk['citing'].isin(sampled_ids) | chunk['cited'].isin(sampled_ids)]
            sampled_citations = pd.concat([sampled_citations, filtered_chunk[['id', 'citing', 'cited']]])

        # Update time remaining estimate
        elapsed_time = time.time() - start_time
        records_processed = len(sampled_citations)
        total_records = len(chunk) * max_iterations  # Approximate total record count
        estimated_time_remaining = (elapsed_time / records_processed) * (total_records - records_processed)
        print(f"Processed {records_processed} citations. Estimated time remaining: {estimated_time_remaining / 60:.2f} minutes.")

        # Stop if we've iterated enough times or hit a reasonable limit
        if len(sampled_citations) >= SAMPLE_SIZE * max_iterations:
            break
    
    # Save sampled citations to a CSV file
    print(len(sampled_citations), " records in sampled citations")
    sampled_citations.to_csv(SAMPLED_CITATIONS_FILE, index=False)
    return sampled_citations

# Function to filter metadata based on sampled citations
def filter_metadata_with_sampled_citations(metadata_batches, sampled_citations_df):
    """
    Filter metadata records based on citing and cited IDs from sampled citations.
    
    Parameters:
        metadata_batches (list of str): List of metadata batch files (e.g., filtered_metadata_batch_1.csv).
        sampled_citations_df (pd.DataFrame): DataFrame containing the sampled citations.
    
    Returns:
        pd.DataFrame: Filtered metadata records.
    """
    sampled_omid_ids = set(sampled_citations_df['citing']).union(set(sampled_citations_df['cited']))
    filtered_metadata = []
    
    start_time = time.time()
    for idx, batch in enumerate(metadata_batches):
        batch_df = pd.read_csv(batch)
        
        # Filter metadata based on 'omid' matching citing or cited IDs
        filtered_batch = batch_df[batch_df['omid'].isin(sampled_omid_ids)]
        filtered_metadata.append(filtered_batch)
        
        # Update time remaining estimate
        elapsed_time = time.time() - start_time
        total_batches = len(metadata_batches)
        estimated_time_remaining = (elapsed_time / (idx + 1)) * (total_batches - (idx + 1))
        print(f"Processed batch {batch}. Estimated time remaining: {estimated_time_remaining / 60:.2f} minutes.")
    
    # Concatenate filtered metadata from all batches
    filtered_metadata_df = pd.concat(filtered_metadata, ignore_index=True)
    
    # Save filtered metadata to CSV
    print(len(filtered_metadata_df), " records in filtered metadata")
    filtered_metadata_df.to_csv(SAMPLED_METADATA_FILE, index=False)
    return filtered_metadata_df


def main():
    # Step 1: Sample and filter citations
    sampled_citations_df = sample_and_filter_citations(CITATIONS_FILE, sample_size=SAMPLE_SIZE)
    
    # Step 2: Filter metadata records based on sampled citations
    sampled_metadata_df = filter_metadata_with_sampled_citations(METADATA_BATCHES, sampled_citations_df)
    
    print(f"Sampled citations saved to: {SAMPLED_CITATIONS_FILE}")
    print(f"Sampled metadata saved to: {SAMPLED_METADATA_FILE}")

if __name__ == "__main__":
    main()
# Out:
# Processed 500 citations. Estimated time remaining: 527.85 minutes.
# Processed 1255 citations. Estimated time remaining: 440.98 minutes.
# Processed 2002 citations. Estimated time remaining: 413.16 minutes.
# Processed 2811 citations. Estimated time remaining: 393.84 minutes.
# Processed 3748 citations. Estimated time remaining: 367.58 minutes.
# Processed 4771 citations. Estimated time remaining: 346.91 minutes.
# Processed 5719 citations. Estimated time remaining: 339.35 minutes.
# 5719  records in sampled citations
# Processed batch filtered_metadata_batch_1.csv. Estimated time remaining: 1.00 minutes.
# Processed batch filtered_metadata_batch_2.csv. Estimated time remaining: 0.86 minutes.
# Processed batch filtered_metadata_batch_3.csv. Estimated time remaining: 0.72 minutes.
# Processed batch filtered_metadata_batch_4.csv. Estimated time remaining: 0.57 minutes.
# Processed batch filtered_metadata_batch_5.csv. Estimated time remaining: 0.43 minutes.
# Processed batch filtered_metadata_batch_6.csv. Estimated time remaining: 0.28 minutes.
# Processed batch filtered_metadata_batch_7.csv. Estimated time remaining: 0.14 minutes.
# Processed batch filtered_metadata_batch_8.csv. Estimated time remaining: 0.00 minutes.
# 6034  records in filtered metadata
# Sampled citations saved to: sampled_citations.csv
# Sampled metadata saved to: sampled_citations_metadata.csv
